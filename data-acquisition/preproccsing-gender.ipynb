# %%
import os

# %%
path = os.getcwd()
print(path)
# Out:
# /media/hossein/9a14f362-81ea-41b1-bc47-0fd70f8f35cd/TavaSystem/resume-persian/data-acquisition

# %%
path = str(path).replace('data-acquisition', '')

# %%
import pandas as pd

# %%
data = pd.read_csv(path + '/data/resume.csv')

# %%
gender = [-1, 0, 1, 2, '']

# %%
import random
i = 0
for item in data['جنسیت']:
    rand = random.randint(0, len(gender)-1)
    data.loc[i, 'جنسیت'] = gender[rand]
    i += 1
data.to_csv(path + '/data/resume.csv', index=False)
print('write successfuly')
# Out:
# /tmp/ipykernel_11448/3669177893.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.loc[i, 'جنسیت'] = gender[rand]
# write successfuly

# %%
data
# Out:
#             نام  نام خانوادگی  \
# 0           علي       ابوذر\n
# 1          محمد        جنتی\n
# 2          مريم    گل محمدی\n
# 3          مهدي       شاملو\n
# 4          حسين    خامنه‌ای\n
# ...         ...           ...
# 4048   يوسف علي      ملکیان\n
# 4049  يوسف مهدي     لاجوردی\n
# 4050       يونا       رفیعی\n
# 4051   يونس رضا       شاملو\n
# 4052   يونس علي  شریعتمداری\n
#
#                                                    آدرس  جنسیت  معدل  \
# 0     خيابان مسعود بخت آزاد (ارباب مهدي) . نبش خيابا...    1.0    21
# 1                             شهرک شریعتی خ ما هان ک 22    1.0    16
# 2       شهرک غرب - بلوار فرهزادی - خ حافظی - نبش دل شاد    0.0    21
# 3     مهراباد جنوبی خ واشقانی فراهانی نبش شامبولی غر...    1.0    24
# 4     ولنجک-انتهای خ 22- گلستان چهارم غربی- بیمارستا...    0.0    24
# ...                                                 ...    ...   ...
# 4048                    چهارراه مخبر الدوله -کوچه رفاهی    1.0    23
# 4049                           سه راه آذری خیابان شبیری    0.0    13
# 4050           تهران پارس  بین عادل زرین وکوچه اذری راد    0.0    24
# 4051  مرزداران غرب . نرسیده به اشرفی اصفهانی . بلوار...    1.0    23
# 4052                       پیچ شمیران خیابان صفی علیشاه    0.0    13
#
#                   مقطع تحصیلی                  رشته تحصیلی  سن  \
# 0           کارشناسی (لیسانس)      علوم ارتباطات اجتماعی\n  51
# 1     کارشناسی ارشد یا بالاتر                       حقوق\n  27
# 2           ابتدایی یا متوسطه             مهندسی راه‌آهن\n  41
# 3                       دیپلم                      شیلات\n  53
# 4                       دیپلم                مهندسی مواد\n  31
# ...                       ...                          ...  ..
# 4048  کارشناسی ارشد یا بالاتر                    پرستاری\n  43
# 4049        ابتدایی یا متوسطه                       حقوق\n  28
# 4050        کارشناسی (لیسانس)   مهندسی ماشین‌های کشاورزی\n  51
# 4051  کارشناسی ارشد یا بالاتر      علوم ارتباطات اجتماعی\n  54
# 4052        ابتدایی یا متوسطه  تلویزیون و هنرهای دیجیتال\n  29
#
#                     مهارت  تجربه کاری(به سال)
# 0                 پلیس \n                   5
# 1                نقاش  \n                   7
# 2          مهندسی نساجی\n                   3
# 3          مهندس معماری\n                  23
# 4                 عکاس \n                  10
# ...                   ...                 ...
# 4048            ماهیگیر\n                   8
# 4049           بازیگر  \n                   7
# 4050              عکاس \n                   8
# 4051  اپراتور لوکوموتیو\n                  23
# 4052              قاضی \n                   0
#
# [4053 rows x 10 columns]
